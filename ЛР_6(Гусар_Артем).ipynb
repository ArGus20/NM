# %% [markdown]
# Варіант 6

# %% [markdown]
# ![зображення.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, expand

x=np.array([-2.,0.,1.,2.], dtype=float)
y=np.array([-11.,-3.,-11.,5.], dtype=float)
x1 = -1.5 # точка, в якій потрібно обчислити значення
x2 = -0.5
x3 = 0.5
x4 = 2.5
def lagrange_interpolation(x, y, x_test):
  n = len(x)
  p = np.zeros(n) # масив для зберігання значень багаточленів L_i
  for i in range(n):
    # обчислюємо багаточлен L_i, який складається з n членів
    # кожен член дорівнює добутку (x-x_j)/(x_i-x_j) для j=0..n, j!=i
    p_i = 1
    for j in range(n):
      if i != j:
        p_i *= (x_test - x[j])/(x[i] - x[j])
    p[i] = p_i
  return np.dot(y, p) # повертаємо значення багаточлена

# обчислюємо інтерполяційний багаточлен та його значення у точці x_test
f1 = lagrange_interpolation(x, y, x1)
print("Значення функції у точці x_1 =", f1.round(4))
f2 = lagrange_interpolation(x, y, x2)
print("Значення функції у точці x_2 =", f2.round(4))
f3 = lagrange_interpolation(x, y, x3)
print("Значення функції у точці x_3 =", f3.round(4))
f4 = lagrange_interpolation(x, y, x4)
print("Значення функції у точці x_4 =", f4.round(4))
# Out:
# Значення функції у точці x_1 = 1.5
# Значення функції у точці x_2 = 2.5
# Значення функції у точці x_3 = -8.5
# Значення функції у точці x_4 = 29.5

# %%
xnew=np.linspace(np.min(x),np.max(x),100) #точки, за якими будуємо графік
ynew=[lagrange_interpolation(x,y,i) for i in xnew]

plt.plot(x,y,'o',xnew,ynew) #будуємо графік функції Лагранжа

plt.plot(x1,f1,'ro')
plt.plot(x2,f2,'ro')
plt.plot(x3,f3,'ro')
plt.plot(x4,f4,'ro')

plt.xlabel('x')
plt.ylabel('y')

plt.title('Lagrange Polynomial_1')
plt.grid(True)
plt.show()

# %%
from scipy.interpolate import lagrange

#Перевірка
f = lagrange(x, y)
fig = plt.figure(figsize = (7,5))
plt.plot(xnew, f(xnew), 'b', x, y, 'ro')
plt.title('Lagrange Polynomial_2')

plt.plot(x1,f1,'o')
plt.plot(x2,f2,'o')
plt.plot(x3,f3,'o')
plt.plot(x4,f4,'o')

plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Варіант 6

# %% [markdown]
# ![зображення.png](data:image/png;base64,...)

# %%
x = np.array([1, 2, 3, 4], dtype=float)

def f_x(x):
  return x / (3*x + 1)

# Обчислюємо значення функції у вузлах
y_data = f_x(x)

print('x', x)
print('f_x(x) =', y_data)
print('shapes:', x.shape, y_data.shape)

# Інтерполяційний поліном Лагранжа
p = lagrange(x, y_data)
print('Поліном Лагранжа р(x):')
print(p)
print('Ступінь полінома:', p.order)

# Точки для графіка
z = np.linspace(np.min(x), np.max(x), 100)

# Графік
plt.plot(z, p(z), '-', label='$L(x)$')
plt.plot(x, y_data, 'o', label='data')
plt.grid(True)
plt.xlabel('x'); plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# x [1. 2. 3. 4.]
# f_x(x) = [0.25       0.28571429 0.3        0.30769231]
# shapes: (4,) (4,)
# Поліном Лагранжа р(x):
#           3           2
# 0.002473 x - 0.02555 x + 0.09505 x + 0.178
# Ступінь полінома: 3

# %%
# Значення функції у вузлах
y_data = f_x(x)

# Точка, у якій інтерполюємо
x_1 = 3.35

def lagrange_interpolation(x, y, x_test):
  n = len(x)
  total = 0.0
  for i in range(n):
    l_i = 1.0
    for j in range(n):
      if i != j:
        l_i *= (x_test - x[j]) / (x[i] - x[j])
    total += y[i] * l_i
  return total

# Значення інтерполяційного полінома у х_1
f1 = lagrange_interpolation(x, y_data, x_1)
print("Значення інтерполяції у точці х_1 =", np.round(f1, 6))
# Out:
# Значення інтерполяції у точці х_1 = 0.302683
