# %% [markdown]
# Варіант 6

# %% [markdown]
# ![Знімок екрана 2026-03-20 091502.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Побудова графіка функції
import numpy as np
import matplotlib.pyplot as plt

# область значень для x та y
x_min, x_max = -2, 2
y_min, y_max = -6, 2
step = 0.01

# створюємо масиви значень x та y
x, y = np.meshgrid(np.arange(x_min, x_max, step),
                   np.arange(y_min, y_max, step))

# рівняння системи
eq1 = np.sin(y) - 2*x - 1.6
eq2 = np.cos(x+0.5) + y - 0.8

# створюємо графік
fig, ax = plt.subplots(figsize=(10, 10))

# додаємо графік першого рівняння
ax.contour(x, y, eq1, levels=[0], colors='red')

# додаємо графік другого рівняння
ax.contour(x, y, eq2, levels=[0], colors='blue')

# налаштування графіка
ax.set_xlim([x_min, x_max])
ax.set_ylim([y_min, y_max])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Графік системи рівнянь')
plt.grid(True)

# показуємо графік
plt.show()

# %%
# Розв'язок системи рівнянь методом простої ітерації
import numpy as np
from scipy import optimize
import math

x0 = 0.15
y0 = -2.1
delta = 0.1

# Функції для ітерацій
def f1(y):
    return (math.sin(y) - 1.6) / 2

def f2(x):
    return 0.8 - math.cos(x + 0.5)

# Метод простої ітерації
def iter(x, y, e):
    xn = x
    yn = y
    n = 0
    while True:
        xn1 = f1(yn)
        yn1 = f2(xn)
        if abs(xn1 - xn) < e and abs(yn1 - yn) < e:
            break
        xn, yn = xn1, yn1
        n += 1
    print('Simple iteration:')
    print('x =', xn1, '\ny =', yn1, '\nThe amount of iteration =', n)

iter(x0, y0, 0.0001)

# Перевірка розв'язку через scipy
def system(vars):
    x, y = vars
    return [
        np.sin(y) - 2*x - 1.6,
        np.cos(x + 0.5) + y - 0.8
    ]

s = optimize.root(system, [0., 0.], method='hybr')
print('Check:', s.x)
# Out:
# Simple iteration:
# x = -0.8665919515423428
# y = -0.13358826350121744
# The amount of iteration = 11
# Check: [-0.86658081 -0.13355833]
