# %% [markdown]
# Варіант 6

# %% [markdown]
# ![зображення.png](data:image/png;base64,...)

# %% [markdown]
# а)

# %%
#Метод Ейлера для розв'язання диф. рівнянь
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
  return x + np.cos(y / 2.25)

a, b, h, y0 = 1.4, 2.4, 0.1, 2.2

# Перевірка вхідних параметрів
if h <= 0:
  print("Крок h повинен бути позитивним.")
  exit()
if a >= b:
  print("Права межа b повинна бути більшою за ліву межу a.")
  exit()

n = int((b - a) / h) # кількість кроків

x = np.array([a + i*h for i in range(n + 1)]) # задаємо x генератором списків

y = np.empty(n + 1)
y[0] = y0

for i in range(n):
  y[i + 1] = y[i] + f(x[i], y[i]) * h

y_rounded = np.round(y, 4)
print("x =", x, "\ny =", y_rounded)

plt.plot(x, y, "o", x, y, "red")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Метод Ейлера")
plt.legend(["точки", "x+cos(y/2.25)"])
plt.grid()
plt.show()
# Out:
# x = [1.4 1.5 1.6 1.7 1.8 1.9 2.  2.1 2.2 2.3 2.4]
# y = [2.2    2.3959 2.5944 2.7949 2.9972 3.2008 3.4056 3.6113 3.8179 4.0253
#  4.2337]

# %%
#Метод Ейлера-Коші
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
  return x + np.cos(y / 2.25)

a, b, h, y0 = 1.4, 2.4, 0.1, 2.2
n = int((b - a) / h) # кількість кроків

# Генерація x, враховуючи останнє значення
x = np.arange(a, b + h, h) # Задати x з включенням b

y = np.empty(n + 1)
y[0] = y0

# Метод Ейлера-Коші
for i in range(n):
  # Використовується середнє значення для нахилу
  y[i + 1] = y[i] + (f(x[i], y[i]) + f(x[i + 1], y[i] + h * f(x[i], y[i]))) * h / 2

y_rounded = np.round(y, 4)

print("x =", x, "\ny =", y_rounded)

# Візуалізація
plt.plot(x, y, "o", x, y, "red")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Метод Ейлера-Коші")
plt.legend(["точки", "x+cos(y/2.25)"])
plt.grid()
plt.show()
# Out:
# x = [1.4 1.5 1.6 1.7 1.8 1.9 2.  2.1 2.2 2.3 2.4]
# y = [2.2    2.3972 2.5966 2.798  3.0008 3.2049 3.4099 3.6159 3.8227 4.0304
#  4.239 ]

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# Функція, що повертає dy/dx
def model(x, y):
  return x + np.cos(y / 2.25)

# Початкова умова
y0 = [2.2]

# Значення x
x = np.linspace(1.4, 2.4, 11)

# Розв'язання ODE
sol = solve_ivp(model, [1.4, 2.4], y0, t_eval=x)

# Виведення результатів
print('x=', sol.t)
print('y=', sol.y[0])

# Побудова графіка результатів
plt.plot(sol.t, sol.y[0], marker='o')
plt.xlabel('x')
plt.ylabel('y(x)')
plt.title('Розв’язання диф. рівняння')
plt.grid()
plt.show()
# Out:
# x= [1.4 1.5 1.6 1.7 1.8 1.9 2.  2.1 2.2 2.3 2.4]
# y= [2.2        2.39719162 2.596676   2.79802057 3.00086246 3.20491799
#  3.40998268 3.61593119 3.82271739 4.03037434 4.23901424]

# %% [markdown]
# б)

# %%
#Метод Ейлера для розв'язання диф. рівнянь
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
  return x + np.sin(y / np.sqrt(10))

a, b, h, y0 = 0.6, 1.6, 0.1, 0.8

# Перевірка вхідних параметрів
if h <= 0:
  print("Крок h повинен бути позитивним.")
  exit()
if a >= b:
  print("Права межа b повинна бути більшою за ліву межу a.")
  exit()

n = int((b - a) / h) # кількість кроків

x = np.array([a + i*h for i in range(n + 1)]) # задаємо x генератором списків

y = np.empty(n + 1)
y[0] = y0

for i in range(n):
  y[i + 1] = y[i] + f(x[i], y[i]) * h

y_rounded = np.round(y, 4)
print("x =", x, "\ny =", y_rounded)

plt.plot(x, y, "o", x, y, "red")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Метод Ейлера")
plt.legend(["точки", "x+sin(y/sqrt(10))"])
plt.grid()
plt.show()
# Out:
# x = [0.6 0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4 1.5 1.6]
# y = [0.8    0.885  0.9827 1.0932 1.2171 1.3547 1.5062 1.6721 1.8525 2.0478
#  2.2581]

# %%
#Метод Ейлера-Коші
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
  return x + np.sin(y / np.sqrt(10))

a, b, h, y0 = 0.6, 1.6, 0.1, 0.8
n = int((b - a) / h) # кількість кроків

# Генерація x, враховуючи останнє значення
x = np.arange(a, b + h, h) # Задати x з включенням b

y = np.empty(n + 1)
y[0] = y0

# Метод Ейлера-Коші
for i in range(n):
  # Використовується середнє значення для нахилу
  y[i + 1] = y[i] + (f(x[i], y[i]) + f(x[i + 1], y[i] + h * f(x[i], y[i]))) * h / 2

y_rounded = np.round(y, 4)

print("x =", x, "\ny =", y_rounded)

# Візуалізація
plt.plot(x, y, "o", x, y, "red")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Метод Ейлера-Коші")
plt.legend(["точки", "x+sin(y/sqrt(10))"])
plt.grid()
plt.show()
# Out:
# x = [0.6 0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4 1.5 1.6]
# y = [0.8    0.8913 0.9956 1.1132 1.2446 1.3899 1.5496 1.724  1.9133 2.1176
#  2.3373]

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# Функція, що повертає dy/dx
def model(x, y):
  return x + np.sin(y / np.sqrt(10))

# Початкова умова
y0 = [0.8] # Потрібно передати як список

# Значення x (від 0.6 до 1.6, 11 точок для кроку 0.1)
x = np.linspace(0.6, 1.6, 11)

# Розв'язання ODE
sol = solve_ivp(model, [0.6, 1.6], y0, t_eval=x)

# Виведення результатів
print('x=', sol.t)
print('y=', np.round(sol.y[0], 4))

# Побудова графіка результатів
plt.plot(sol.t, sol.y[0], marker='o')
plt.xlabel('x')
plt.ylabel('y(x)')
plt.title('Розв’язання диф. рівняння (solve_ivp)')
plt.grid()
plt.show()
# Out:
# x= [0.6 0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4 1.5 1.6]
# y= [0.8    0.8914 0.9957 1.1134 1.2448 1.3903 1.5501 1.7246 1.914  2.1184
#  2.3381]
